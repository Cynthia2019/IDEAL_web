# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv('data/2D.csv')

# %%
df.head()
# Out:
#   symmetry  unit_cell_x_pixels  unit_cell_y_pixels  geometry_condensed  \
# 0      C2v                  50                  50                 NaN
# 1      C2v                  50                  50                 NaN
# 2      C2v                  50                  50                 NaN
# 3      C2v                  50                  50                 NaN
# 4      C2v                  50                  50                 NaN
#
#                                        geometry_full     condition  \
# 0  0000000000000001111111111111111111100000000000...  Plane Strain
# 1  0000000000000000111111111111111111000000000000...  Plane Strain
# 2  0000000000000000001111111111111100000000000000...  Plane Strain
# 3  0000000000000000001111111111111100000000000000...  Plane Strain
# 4  0000000000000000001111111111111100000000000000...  Plane Strain
#
#            C11          C12          C22  C16  ...  CM0_C16  CM0_C26 CM0_C66  \
# ...

# %%
df.columns
# Out:
# Index(['symmetry', 'unit_cell_x_pixels', 'unit_cell_y_pixels',
#        'geometry_condensed', 'geometry_full', 'condition', 'C11', 'C12', 'C22',
#        'C16', 'C26', 'C66', 'CM0', 'CM0_C11', 'CM0_C12', 'CM0_C22', 'CM0_C16',
#        'CM0_C26', 'CM0_C66', 'CM1', 'CM1_C11', 'CM1_C12', 'CM1_C22', 'CM1_C16',
#        'CM1_C26', 'CM1_C66'],
#       dtype='object')
